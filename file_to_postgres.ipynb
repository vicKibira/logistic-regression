# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
con = "postgresql://root:root@localhost:5432/bank"

# %%
engine = create_engine(con)

# %%
engine.connect()

# %%
query = '''
CREATE DATABASE IF NOT EXISTS bankdets;
'''

# %%
df = pd.read_csv('bank-full-dataset.csv')

# %%
df
# Out:
#        Unnamed: 0  age           job   marital  education default  balance  \
# 0               0   58    management   married   tertiary      no     2143
# 1               1   44    technician    single  secondary      no       29
# 2               2   33  entrepreneur   married  secondary      no        2
# 3               3   47   blue-collar   married        NaN      no     1506
# 4               4   33           NaN    single        NaN      no        1
# ...           ...  ...           ...       ...        ...     ...      ...
# 45206       45206   51    technician   married   tertiary      no      825
# 45207       45207   71       retired  divorced    primary      no     1729
# 45208       45208   72       retired   married  secondary      no     5715
# 45209       45209   57   blue-collar   married  secondary      no      668
# 45210       45210   37  entrepreneur   married  secondary      no     2971
#
# ...

# %%
df
# Out:
#        Unnamed: 0  age           job   marital  education default  balance  \
# 0               0   58    management   married   tertiary      no     2143
# 1               1   44    technician    single  secondary      no       29
# 2               2   33  entrepreneur   married  secondary      no        2
# 3               3   47   blue-collar   married        NaN      no     1506
# 4               4   33           NaN    single        NaN      no        1
# ...           ...  ...           ...       ...        ...     ...      ...
# 45206       45206   51    technician   married   tertiary      no      825
# 45207       45207   71       retired  divorced    primary      no     1729
# 45208       45208   72       retired   married  secondary      no     5715
# 45209       45209   57   blue-collar   married  secondary      no      668
# 45210       45210   37  entrepreneur   married  secondary      no     2971
#
# ...

# %%
print(pd.io.sql.get_schema(df, name='bank_data'))
# Out:
# CREATE TABLE "bank_data" (
# "Unnamed: 0" INTEGER,
#   "age" INTEGER,
#   "job" TEXT,
#   "marital" TEXT,
#   "education" TEXT,
#   "default" TEXT,
#   "balance" INTEGER,
#   "housing" TEXT,
#   "loan" TEXT,
#   "contact" TEXT,
#   "day" INTEGER,
#   "month" TEXT,
#   "duration" INTEGER,
#   "campaign" INTEGER,
#   "pdays" INTEGER,
#   "previous" INTEGER,
#   "poutcome" TEXT,
#   "y" TEXT
# )

# %%
df.head(n=0).to_sql(name='bank_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
df_iter = pd.read_csv('bank-full-dataset.csv', chunksize=10000, iterator=True)

# %%
df = next(df_iter)

# %%
df
# Out:
#       Unnamed: 0  age           job  marital  education default  balance  \
# 0              0   58    management  married   tertiary      no     2143
# 1              1   44    technician   single  secondary      no       29
# 2              2   33  entrepreneur  married  secondary      no        2
# 3              3   47   blue-collar  married        NaN      no     1506
# 4              4   33           NaN   single        NaN      no        1
# ...          ...  ...           ...      ...        ...     ...      ...
# 9995        9995   49     housemaid  married    primary      no     3376
# 9996        9996   52  entrepreneur  married   tertiary      no     1115
# 9997        9997   40   blue-collar  married    primary      no       48
# 9998        9998   46      services  married   tertiary      no      474
# 9999        9999   42    technician  married  secondary      no     8036
#
#      housing loan  contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
while True:
    try:
        df  = next(df_iter)
        df.to_sql(name='bank_data', con=engine, if_exists='append')
    except Exception as e:
        print('An error occured')
